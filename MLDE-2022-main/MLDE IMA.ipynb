# %% [markdown]
# # Pre-processed data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
os.chdir(r'C:\Users\Perry_Lu\Desktop\ebm\正课\课程\MLDE\IMA\data\brazilian-ecommerce')

# %%
df_order = pd.read_csv('olist_order_items_dataset.csv')
df_order.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_grouped= df_order.groupby(df_order['order_id']).sum()
df_grouped.head()
# Out:
#                                   order_item_id   price  freight_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              1   58.90          13.29
# 00018f77f2f0320c557190d7a144bdd3              1  239.90          19.93
# 000229ec398224ef6ca0657da4fc703e              1  199.00          17.87
# 00024acbcdf0a6daa1e931b038114c75              1   12.99          12.79
# 00042b26cf59d7ce69dfabb4e55b4fd9              1  199.90          18.14

# %%
df_grouped=df_grouped.rename(columns={'price':'order_price'})
df_grouped
# Out:
#                                   order_item_id  order_price  freight_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214              1        58.90          13.29
# 00018f77f2f0320c557190d7a144bdd3              1       239.90          19.93
# 000229ec398224ef6ca0657da4fc703e              1       199.00          17.87
# 00024acbcdf0a6daa1e931b038114c75              1        12.99          12.79
# 00042b26cf59d7ce69dfabb4e55b4fd9              1       199.90          18.14
# ...                                         ...          ...            ...
# fffc94f6ce00a00581880bf54a75a037              1       299.99          43.41
# fffcd46ef2263f404302a634eb57f7eb              1       350.00          36.53
# fffce4705a9662cd70adb13d4a31832d              1        99.90          16.95
# fffe18544ffabc95dfada21779c9644f              1        55.99           8.72
# fffe41c64501cc87c801fd61db3f6244              1        43.00          12.79
#
# [98666 rows x 3 columns]

# %%
df_grouped = df_grouped.reset_index()
df_grouped = df_grouped.iloc[:,[0,2]]
df_grouped
# Out:
#                                order_id  order_price
# 0      00010242fe8c5a6d1ba2dd792cb16214        58.90
# 1      00018f77f2f0320c557190d7a144bdd3       239.90
# 2      000229ec398224ef6ca0657da4fc703e       199.00
# 3      00024acbcdf0a6daa1e931b038114c75        12.99
# 4      00042b26cf59d7ce69dfabb4e55b4fd9       199.90
# ...                                 ...          ...
# 98661  fffc94f6ce00a00581880bf54a75a037       299.99
# 98662  fffcd46ef2263f404302a634eb57f7eb       350.00
# 98663  fffce4705a9662cd70adb13d4a31832d        99.90
# 98664  fffe18544ffabc95dfada21779c9644f        55.99
# 98665  fffe41c64501cc87c801fd61db3f6244        43.00
#
# [98666 rows x 2 columns]

# %%
df_left = df_order.iloc[:,[0,2]]
df_left
# Out:
#                                 order_id                        product_id
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
# [112650 rows x 2 columns]

# %%
df=pd.read_csv('olist_products_dataset.csv')
df=df.drop(['product_category_name','product_name_lenght','product_weight_g','product_length_cm','product_height_cm','product_width_cm'],axis=1)
df
# Out:
#                              product_id  product_description_lenght  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                       287.0
# 1      3aa071139cb16b67ca9e5dea641aaa2f                       276.0
# 2      96bd76ec8810374ed1b65e291975717f                       250.0
# 3      cef67bcfe19066a932b7673e239eb23d                       261.0
# 4      9dc1a7de274444849c219cff195d0b71                       402.0
# ...                                 ...                         ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                        67.0
# 32947  bf4538d88321d0fd4412a93c974510e6                       971.0
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                       799.0
# 32949  83808703fc0706a22e264b9d75f04a2e                       156.0
# 32950  106392145fca363410d287a815be6de4                       309.0
#
#        product_photos_qty
# 0                     1.0
# 1                     1.0
# 2                     1.0
# 3                     1.0
# ...

# %%
df = pd.merge(df_left,df,how='left')
df
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 112645  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 112646  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 112647  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 112648  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 112649  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
#         product_description_lenght  product_photos_qty
# ...

# %%
df = df.groupby(['order_id']).mean().reset_index()
df
# Out:
#                                order_id  product_description_lenght  \
# 0      00010242fe8c5a6d1ba2dd792cb16214                       598.0
# 1      00018f77f2f0320c557190d7a144bdd3                       239.0
# 2      000229ec398224ef6ca0657da4fc703e                       695.0
# 3      00024acbcdf0a6daa1e931b038114c75                       480.0
# 4      00042b26cf59d7ce69dfabb4e55b4fd9                       409.0
# ...                                 ...                         ...
# 98661  fffc94f6ce00a00581880bf54a75a037                      1002.0
# 98662  fffcd46ef2263f404302a634eb57f7eb                       232.0
# 98663  fffce4705a9662cd70adb13d4a31832d                       869.0
# 98664  fffe18544ffabc95dfada21779c9644f                      1306.0
# 98665  fffe41c64501cc87c801fd61db3f6244                       511.0
#
#        product_photos_qty
# 0                     4.0
# 1                     2.0
# 2                     2.0
# 3                     1.0
# ...

# %%
df = pd.merge(df_grouped,df)
df
# Out:
#                                order_id  order_price  \
# 0      00010242fe8c5a6d1ba2dd792cb16214        58.90
# 1      00018f77f2f0320c557190d7a144bdd3       239.90
# 2      000229ec398224ef6ca0657da4fc703e       199.00
# 3      00024acbcdf0a6daa1e931b038114c75        12.99
# 4      00042b26cf59d7ce69dfabb4e55b4fd9       199.90
# ...                                 ...          ...
# 98661  fffc94f6ce00a00581880bf54a75a037       299.99
# 98662  fffcd46ef2263f404302a634eb57f7eb       350.00
# 98663  fffce4705a9662cd70adb13d4a31832d        99.90
# 98664  fffe18544ffabc95dfada21779c9644f        55.99
# 98665  fffe41c64501cc87c801fd61db3f6244        43.00
#
#        product_description_lenght  product_photos_qty
# 0                           598.0                 4.0
# 1                           239.0                 2.0
# 2                           695.0                 2.0
# 3                           480.0                 1.0
# ...

# %%
df_payment=pd.read_csv('olist_order_payments_dataset.csv')
df_payment
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
df_payment = df_payment.iloc[:,[0,-1]]
df_payment
# Out:
#                                 order_id  payment_value
# 0       b81ef226f3fe1789b1e8b2acac839d17          99.33
# 1       a9810da82917af2d9aefd1278f1dcfa0          24.39
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd          65.71
# 3       ba78997921bbcdc1373bb41e913ab953         107.78
# 4       42fdf880ba16b47b59251dd489d4441a         128.45
# ...                                  ...            ...
# 103881  0406037ad97740d563a178ecc7a2075c         363.31
# 103882  7b905861d7c825891d6347454ea7863f          96.80
# 103883  32609bbb3dd69b3c066a6860554a77bf          47.77
# 103884  b8b61059626efa996a60be9bb9320e10         369.54
# 103885  28bbae6599b09d39ca406b747b6632b1         191.58
#
# [103886 rows x 2 columns]

# %%
df
# Out:
#                                order_id  order_price  \
# 0      00010242fe8c5a6d1ba2dd792cb16214        58.90
# 1      00018f77f2f0320c557190d7a144bdd3       239.90
# 2      000229ec398224ef6ca0657da4fc703e       199.00
# 3      00024acbcdf0a6daa1e931b038114c75        12.99
# 4      00042b26cf59d7ce69dfabb4e55b4fd9       199.90
# ...                                 ...          ...
# 98661  fffc94f6ce00a00581880bf54a75a037       299.99
# 98662  fffcd46ef2263f404302a634eb57f7eb       350.00
# 98663  fffce4705a9662cd70adb13d4a31832d        99.90
# 98664  fffe18544ffabc95dfada21779c9644f        55.99
# 98665  fffe41c64501cc87c801fd61db3f6244        43.00
#
#        product_description_lenght  product_photos_qty
# 0                           598.0                 4.0
# 1                           239.0                 2.0
# 2                           695.0                 2.0
# 3                           480.0                 1.0
# ...

# %%
df_merge=pd.merge(df,df_payment)
df_merge.head()
# Out:
#                            order_id  order_price  product_description_lenght  \
# 0  00010242fe8c5a6d1ba2dd792cb16214        58.90                       598.0
# 1  00018f77f2f0320c557190d7a144bdd3       239.90                       239.0
# 2  000229ec398224ef6ca0657da4fc703e       199.00                       695.0
# 3  00024acbcdf0a6daa1e931b038114c75        12.99                       480.0
# 4  00042b26cf59d7ce69dfabb4e55b4fd9       199.90                       409.0
#
#    product_photos_qty  payment_value
# 0                 4.0          72.19
# 1                 2.0         259.83
# 2                 2.0         216.87
# 3                 1.0          25.78
# 4                 1.0         218.04

# %%
df_merge['shipping_price']=df_merge['payment_value']-df_merge['order_price']
df_merge.head()
# Out:
#                            order_id  order_price  product_description_lenght  \
# 0  00010242fe8c5a6d1ba2dd792cb16214        58.90                       598.0
# 1  00018f77f2f0320c557190d7a144bdd3       239.90                       239.0
# 2  000229ec398224ef6ca0657da4fc703e       199.00                       695.0
# 3  00024acbcdf0a6daa1e931b038114c75        12.99                       480.0
# 4  00042b26cf59d7ce69dfabb4e55b4fd9       199.90                       409.0
#
#    product_photos_qty  payment_value  shipping_price
# 0                 4.0          72.19           13.29
# 1                 2.0         259.83           19.93
# 2                 2.0         216.87           17.87
# 3                 1.0          25.78           12.79
# 4                 1.0         218.04           18.14

# %%
df_merge['shipping_ratio']=df_merge['shipping_price']/df_merge['order_price']
df_merge.head()                                                                                #???
# Out:
#                            order_id  order_price  product_description_lenght  \
# 0  00010242fe8c5a6d1ba2dd792cb16214        58.90                       598.0
# 1  00018f77f2f0320c557190d7a144bdd3       239.90                       239.0
# 2  000229ec398224ef6ca0657da4fc703e       199.00                       695.0
# 3  00024acbcdf0a6daa1e931b038114c75        12.99                       480.0
# 4  00042b26cf59d7ce69dfabb4e55b4fd9       199.90                       409.0
#
#    product_photos_qty  payment_value  shipping_price  shipping_ratio
# 0                 4.0          72.19           13.29        0.225637
# 1                 2.0         259.83           19.93        0.083076
# 2                 2.0         216.87           17.87        0.089799
# 3                 1.0          25.78           12.79        0.984604
# 4                 1.0         218.04           18.14        0.090745

# %%
df_merge.iloc[:,[0,-1,2,3]]
# Out:
#                                 order_id  shipping_ratio  \
# 0       00010242fe8c5a6d1ba2dd792cb16214        0.225637
# 1       00018f77f2f0320c557190d7a144bdd3        0.083076
# 2       000229ec398224ef6ca0657da4fc703e        0.089799
# 3       00024acbcdf0a6daa1e931b038114c75        0.984604
# 4       00042b26cf59d7ce69dfabb4e55b4fd9        0.090745
# ...                                  ...             ...
# 103051  fffc94f6ce00a00581880bf54a75a037        0.144705
# 103052  fffcd46ef2263f404302a634eb57f7eb        0.104371
# 103053  fffce4705a9662cd70adb13d4a31832d        0.169670
# 103054  fffe18544ffabc95dfada21779c9644f        0.155742
# 103055  fffe41c64501cc87c801fd61db3f6244        0.297442
#
#         product_description_lenght  product_photos_qty
# 0                            598.0                 4.0
# 1                            239.0                 2.0
# 2                            695.0                 2.0
# 3                            480.0                 1.0
# ...

# %%
order_review = pd.read_csv('olist_order_reviews_dataset.csv')
df_review=pd.DataFrame
df_review=order_review
df_score = df_review.drop(['review_id','review_comment_title','review_comment_message','review_creation_date','review_answer_timestamp'], axis = 1)
df_score.head()
conditions = [
    (df_score['review_score'] <= 3),
    (df_score['review_score'] > 3) & (df_score['review_score'] <= 4),
    (df_score['review_score'] > 4) & (df_score['review_score'] <= 5),
    ]
values = ['0', '1', '2']
df_score['classification_1'] = np.select(conditions, values)
another_conditions = [
    (df_score['review_score'] <= 3),
    (df_score['review_score'] > 3) & (df_score['review_score'] <= 5),
    ]
another_values = ['0', '1']
df_score['classification_2'] = np.select(another_conditions,another_values)
df_score.head()
# Out:
#                            order_id  review_score classification_1  \
# 0  00010242fe8c5a6d1ba2dd792cb16214             5                2
# 1  00018f77f2f0320c557190d7a144bdd3             4                1
# 2  000229ec398224ef6ca0657da4fc703e             5                2
# 3  00024acbcdf0a6daa1e931b038114c75             4                1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9             5                2
#
#   classification_2
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
dataset = pd.read_csv('olist_orders_dataset.csv')
dif = dataset.iloc[:,6:]
columns_index=dataset.iloc[:,0]
columns_index.head()

order_time_delivered = dif.iloc[:,0]
order_time_estimated = dif.iloc[:,1]

order_time_delivered = pd.to_datetime(order_time_delivered)
order_time_estimated = pd.to_datetime(order_time_estimated)

delivery_differnce = order_time_estimated-order_time_delivered
delivery_differnce = delivery_differnce.dt.days

df_order=pd.DataFrame(columns_index)
df_order['Difference_between_estimated_to_delivered']=delivery_differnce
df_order.head()
# Out:
#                            order_id  Difference_between_estimated_to_delivered
# 0  e481f51cbdc54678b7cc49136f2d6af7                                        7.0
# 1  53cdb2fc8bc7dce0b6741e2150273451                                        5.0
# 2  47770eb9100c2d0c44946d9cf07ec65d                                       17.0
# 3  949d5b44dbf5de918fe9c16f97b45f8a                                       12.0
# 4  ad21c59c0840e6cb83a9ceb5573f8159                                        9.0

# %%
df_merge2=pd.merge(df_merge,df_score)
df_merge3=pd.merge(df_merge2,df_order)
df_merge3=df_merge3.drop(['order_price','shipping_price','payment_value'],axis=1)
df_merge3 = df_merge3.iloc[:,[1,2,3,-1,4,5,6]]
df_merge3
# Out:
#        product_description_lenght  product_photos_qty  shipping_ratio  \
# 0                           598.0                 4.0        0.225637
# 1                           239.0                 2.0        0.083076
# 2                           695.0                 2.0        0.089799
# 3                           480.0                 1.0        0.984604
# 4                           409.0                 1.0        0.090745
# ...                           ...                 ...             ...
# 93265                      1002.0                 3.0        0.144705
# 93266                       232.0                 1.0        0.104371
# 93267                       869.0                 1.0        0.169670
# 93268                      1306.0                 1.0        0.155742
# 93269                       511.0                 1.0        0.297442
#
#        Difference_between_estimated_to_delivered  review_score  \
# ...

# %% [markdown]
# # Wordcloud

# %%
def getText():
    txt = open(r'C:\Users\Perry_Lu\Desktop\python\wordcloud_IMA.txt','r',encoding='gb18030', errors='ignore').read()
    txt = txt.lower()
    for ch in '!"#$%&()*+,-./:;<=>?@[\\]^_‘{|}~¬':
        txt = txt.replace(ch, " ")   #将文本中特殊字符替换为空格
    return txt

hamletTxt = getText()
words  = hamletTxt.split()
counts = {}
for word in words:			
    if word not in ('the','i','it','not','to','very','is','of','and','a','was','in','on','my','have','with','for','but','good'):
        counts[word] = counts.get(word,0) + 1
items = list(counts.items())
items.sort(key=lambda x:x[1], reverse=True) 
for i in range(10):
    word, count = items[i]
    print ("{0:<10}{1:>5}".format(word, count))
# Out:
# product     441
# arrived     142
# received    142
# delivery    138
# before      123
# delivered   122
# time        118
# deadline    105
# recommend    97
# bought       92

# %%
import numpy as np
import wordcloud
import PIL.Image as image

# f = open(r'C:\Users\Perry_Lu\Desktop\python\word.txt','r',encoding='utf-8')
# t = f.read()
# f.close()
# ls = jieba.lcut(t)
# result = []

# for words in ls:
#     if words in ('我的','\n','非常','而且','没有','一个') or len(words) == 1:
#         continue
#     result.append(words)

def getText():
    txt = open(r'C:\Users\Perry_Lu\Desktop\python\wordcloud_IMA.txt','r',encoding='gb18030', errors='ignore').read()
    txt = txt.lower()
    for ch in '!"#$%&()*+,-./:;<=>?@[\\]^_‘{|}~¬':
        txt = txt.replace(ch, " ")   #将文本中特殊字符替换为空格
    return txt

hamletTxt = getText()
result  = hamletTxt.split()
    
txt = ' '.join(result)
mask = np.array(image.open(r"C:\Users\Perry_Lu\Desktop\python\fig.jpeg"))
w = wordcloud.WordCloud(mask = mask, font_path='msyh.ttc',width= 1000, height= 700, background_color= 'white')
w.generate(txt)
w.to_file(r'C:\Users\Perry_Lu\Desktop\python\wordcloud_IMA.png')

# %%
from PIL import Image
Image.open(r'C:\Users\Perry_Lu\Desktop\python\wordcloud_IMA.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x476 at 0x295F6DE6B80>

# %% [markdown]
# # Model

# %% [markdown]
# ## Binary classification

# %%
result_2 = {}

# %% [markdown]
# ### Random Forest Classification

# %%
# Random Forest Classification

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# Importing the dataset
dataset = pd.read_csv('dataset.csv')
dataset = dataset.dropna().reset_index(drop=True)
X = dataset.iloc[:,2:6].values
y = dataset.iloc[:,-1].values
print(set(y))
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)#数据集比例划分

# Feature Scaling
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

from sklearn.model_selection import GridSearchCV

tuned_parameters = [{
                     'max_depth': [3, 5, 7],
                     'min_samples_split': [3, 5, 7],
                     'max_features': ["sqrt", "log2", None]}]

scores = [ 'f1_macro']

for score in scores:
    print("# Tuning hyperparameters for %s" % score)
    print("\n")
    clf = GridSearchCV(RandomForestClassifier(class_weight="balanced"), tuned_parameters, cv=5,
                       scoring= score)
    clf.fit(X_train, y_train)
    print("Best parameters set found on the training set:")
    print(clf.best_params_)
    print("\n")
# Out:
# {0, 1}
# # Tuning hyperparameters for f1_macro
#
#
# Best parameters set found on the training set:
# {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 7}

# %%
#  Fitting Random Forest to the Training set
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0,class_weight = 'balanced',max_depth= 3, max_features= 'log2', min_samples_split= 7 )
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(y_test,y_pred,average="binary")}')
result_2['Random_forest'] = f1_score(y_test,y_pred,average='binary')
# Out:
# confusion_matrix is:
# [[ 1222  3636]
#  [  611 17019]]
# f1_score is: 0.8890688259109312

# %% [markdown]
# ### Logistic Regression

# %%
# Logistic Regression

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('dataset.csv')
dataset = dataset.dropna().reset_index(drop=True)
X = dataset.iloc[:,2:6].values
y = dataset.iloc[:,-1].values
print(set(y))
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)#数据集比例划分
# Out:
# {0, 1}

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0,class_weight = 'balanced')
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix , f1_score
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 2550,  2308],
#        [ 6373, 11257]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(y_test,y_pred,average="binary")}')
result_2['Logistic_regression'] = f1_score(y_test,y_pred,average='binary')
# Out:
# confusion_matrix is:
# [[ 2550  2308]
#  [ 6373 11257]]
# f1_score is: 0.7217182240743709

# %% [markdown]
# ### Support Vector Machine

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('dataset.csv')
dataset = dataset.dropna().reset_index(drop=True)
X = dataset.iloc[:,2:6].values
y = dataset.iloc[:,-1].values
print(set(y))

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting SVM to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0,class_weight = 'balanced')
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)
# Out:
# {0, 1}

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(y_test,y_pred,average="binary")}')
result_2['Support_vector_Machine'] = f1_score(y_test,y_pred,average='binary')
# Out:
# confusion_matrix is:
# [[ 1951  2907]
#  [ 3394 14236]]
# f1_score is: 0.8187961924481637

# %% [markdown]
# ### Decision Tree

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier as DTC


# Importing the dataset
dataset = pd.read_csv('dataset.csv')
dataset = dataset.dropna().reset_index(drop=True)
X = dataset.iloc[:,2:6].values
y = dataset.iloc[:,-1].values
print(set(y))

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
# from sklearn.preprocessing import StandardScaler
# sc_X = StandardScaler()
# X_train = sc_X.fit_transform(X_train)
# X_test = sc_X.transform(X_test)

from sklearn.model_selection import GridSearchCV

tuned_parameters = [{'criterion': ['gini', 'entropy'],
                     'max_depth': [3, 5, 7],
                     'min_samples_split': [3, 5, 7],
                     'max_features': ["sqrt", "log2", None]}]

scores = ['f1_macro']

for score in scores:
    print("# Tuning hyperparameters for %s" % score)
    print("\n")
    clf = GridSearchCV(DTC(class_weight="balanced"), tuned_parameters, cv=5,
                       scoring= score)
    clf.fit(X_train, y_train)
    print("Best parameters set found on the training set:")
    print(clf.best_params_)
    print("\n")
# Out:
# {0, 1}
# # Tuning hyperparameters for f1_macro
#
#
# Best parameters set found on the training set:
# {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_split': 3}

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion ='entropy', max_depth = 5, class_weight='balanced', max_features = None , min_samples_split = 3)
classifier.fit(X_train,y_train)

# # Predicting the Test set results
y_pred = classifier.predict(X_test)

# # Making the Confusion Matrix
from sklearn.metrics import confusion_matrix,f1_score
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 1346,  2600],
#        [ 1724, 12321]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(y_test,y_pred,average="binary")}')
result_2['Decision_tree'] = f1_score(y_test,y_pred,average='binary')
# Out:
# confusion_matrix is:
# [[ 1346  2600]
#  [ 1724 12321]]
# f1_score is: 0.8507215355934543

# %% [markdown]
# ### Neural Network

# %%
import h5py
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.python.framework.ops import EagerTensor
from tensorflow.python.ops.resource_variable_ops import ResourceVariable
from sklearn.model_selection  import train_test_split
import pandas as pd
import math
import time

# %%
df = pd.read_csv(r'C:/Users/Perry_Lu/Desktop/ebm/正课/课程/MLDE/IMA/data/brazilian-ecommerce/dataset.csv')
df = df.iloc[:,2:]
df

df['product_description_lenght'] = df['product_description_lenght'].astype('float64')
df['shippinproduct_photos_qtyg_ratio'] = df['product_photos_qty'].astype('float64')
df['shipping_ratio'] = df['shipping_ratio'].astype('float64')
df['Difference_between_estimated_to_delivered'] = df['Difference_between_estimated_to_delivered'].astype('float64')

df = df.dropna().reset_index(drop = True)
df

X = df.iloc[:,:4]
X

Y = df.iloc[:,-2]
Y
print(set(Y))
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
# Out:
# {0, 1}

# %%
X_train = X_train.values.T
X_test = X_test.values.T
Y_train = Y_train[np.newaxis,:]
Y_test = Y_test[np.newaxis,:]
# Out:
# <ipython-input-276-4fcb5a565a52>:3: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Y_train = Y_train[np.newaxis,:]
# <ipython-input-276-4fcb5a565a52>:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Y_test = Y_test[np.newaxis,:]

# %%
X_train.shape
# Out:
# (4, 71961)

# %%
Y_train.shape
# Out:
# (1, 71961)

# %%
def layer_sizes(X, Y):
    n_x = X.shape[0]
    n_h = 4
    n_y = Y.shape[0]
    return (n_x, n_h, n_y)

# %%
def initialize_parameters(n_x, n_h, n_y):

    W1 = np.random.randn(n_h,n_x)*0.01
    b1 = np.zeros((n_h,1))
    W2 = np.random.randn(n_y,n_h)*0.01
    b2 = np.zeros((n_y,1))

    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
def sigmoid(z):
    return (1/(1 + np.exp(-z)))

# %%
def forward_propagation(X, parameters):
  
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    
    Z1 = np.dot(W1,X)+b1
    A1 = np.tanh(Z1)
    Z2 = np.dot(W2,A1)+b2
    A2 = sigmoid(Z2)
    
    assert(A2.shape == (1, X.shape[1]))
    
    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
def compute_cost(A2, Y):

    m = Y.shape[1] # number of examples

    cost = -1/m*(np.dot(Y,np.log(A2).T)+np.dot((1-Y),np.log(1-A2).T))
    
    cost = float(np.squeeze(cost))  # makes sure cost is the dimension we expect. 
    
    return cost

# %%
def backward_propagation(parameters, cache, X, Y):
   
    m = X.shape[1]
    
    W1 = parameters['W1']
    W2 = parameters['W2']

    A1 = cache['A1']
    A2 = cache['A2']
    Z1 = cache['Z1']

    dZ2 = A2 - Y
    dW2 = np.dot(dZ2,A1.T)/m
    db2 = np.sum(dZ2,axis = 1,keepdims = True)/m
    dZ1 = np.dot(W2.T,dZ2)*(1-np.power(A1,2))
    dW1 = np.dot(dZ1,X.T)/m
    db1 = np.sum(dZ1,axis = 1,keepdims = True)/m
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

# %%
def update_parameters(parameters, grads, learning_rate = 0.12):

    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    
    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']

    W1 = W1 - learning_rate*dW1
    b1 = b1 - learning_rate*db1
    W2 = W2 - learning_rate*dW2
    b2 = b2 - learning_rate*db2
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
def nn_model(X, Y, n_h, num_iterations = 10000, print_cost=False):
    
    np.random.seed(3)
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
    parameters = initialize_parameters(n_x,n_h,n_y)

    for i in range(0, num_iterations):
         
        A2, cache = forward_propagation(X, parameters)
        cost = compute_cost(A2, Y)
        grads = backward_propagation(parameters, cache, X, Y)
        parameters = update_parameters(parameters, grads)
        
        if print_cost and i % 10 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
def predict(parameters, X):
    
    A2, cache = forward_propagation(X, parameters)
    print(A2)
    predictions = (A2 > 0.78608586)
    
    return predictions

# %%
parameters = nn_model(X_train, Y_train, n_h = 10, num_iterations = 100, print_cost=True)
# Out:
# Cost after iteration 0: 0.691195
# Cost after iteration 10: 0.519644
# Cost after iteration 20: 0.519093
# Cost after iteration 30: 0.519288
# Cost after iteration 40: 0.519135
# Cost after iteration 50: 0.519122
# Cost after iteration 60: 0.519100
# Cost after iteration 70: 0.518936
# Cost after iteration 80: 0.519183
# Cost after iteration 90: 0.520472

# %%
Y_test = Y_test[0]

# %%
predictions = predict(parameters, X_test)
predictions = predictions.astype(int)[0]
predictions
print ('Accuracy: %d' % float((np.dot(Y_test, predictions.T) + np.dot(1 - Y_test, 1 - predictions.T)) / float(Y_test.size) * 100) + '%')
# Out:
# [[0.78811312 0.78811312 0.78811312 ... 0.78811312 0.78811312 0.78811265]]
# Accuracy: 77%

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(Y_test, predictions)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(Y_test,predictions,average="binary")}')
result_2['Neural_network'] = f1_score(Y_test,predictions,average='binary')
# Out:
# confusion_matrix is:
# [[   82  3850]
#  [  263 13796]]
# f1_score is: 0.8702728276297114

# %% [markdown]
# ### result

# %%
result_2
# Out:
# {'Support_vector_Machine': 0.8187961924481637,
#  'Logistic_regression': 0.7217182240743709,
#  'Decision_tree': 0.8507215355934543,
#  'Neural_network': 0.8702728276297114,
#  'Random_forest': 0.8890688259109312}

# %%
fig,ax = plt.subplots(figsize = (8,4))
ax.plot(list(result_2.values()))
ax.set_xticks(np.arange(5))
ax.set_xticklabels(result_2.keys())
ax.set_xlabel('Algorithms',size = 15)
ax.set_ylabel('F1-score',size = 15)
ax.set_title('Binary Classification',size = 15)
# Out:
# Text(0.5, 1.0, 'Binary Classification')

# %% [markdown]
# ## 3Class Classification

# %%
# store the result of every algorithm
result = {}

# %% [markdown]
# ### Random Forest Classification

# %%
# Random Forest Classification

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# Importing the dataset
dataset = pd.read_csv('dataset.csv')
dataset = dataset.dropna().reset_index(drop=True)
X = dataset.iloc[:,2:6].values
y = dataset.iloc[:,-2].values
print(set(y))
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)#数据集比例划分

# Feature Scaling
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_train = sc.fit_transform(X_train)
# X_test = sc.transform(X_test)

from sklearn.model_selection import GridSearchCV

tuned_parameters = [{
                     'max_depth': [3, 5, 7],
                     'min_samples_split': [3, 5, 7],
                     'max_features': ["sqrt", "log2", None]}]

scores = ['f1_macro']

for score in scores:
    print("# Tuning hyperparameters for %s" % score)
    print("\n")
    clf = GridSearchCV(RandomForestClassifier(class_weight="balanced"), tuned_parameters, cv=5,
                       scoring= score)
    clf.fit(X_train, y_train)
    print("Best parameters set found on the training set:")
    print(clf.best_params_)
    print("\n")
# Out:
# {0, 1, 2}
# # Tuning hyperparameters for f1_macro
#
#
# Best parameters set found on the training set:
# {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 7}

# %%
#  Fitting Random Forest to the Training set
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0,class_weight = 'balanced',max_depth= 5, max_features= 'sqrt', min_samples_split= 7 )
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(y_test,y_pred,average="macro")}')
result['Random_forest'] = f1_score(y_test,y_pred,average='macro')
# Out:
# confusion_matrix is:
# [[1286 1075 2497]
#  [ 246 1311 2932]
#  [ 523 3356 9262]]
# f1_score is: 0.4312991351436101

# %% [markdown]
# ### Logistic Regression

# %%
# Logistic Regression

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('dataset.csv')
dataset = dataset.dropna().reset_index(drop=True)
X = dataset.iloc[:,2:6].values
y = dataset.iloc[:,-2].values
print(set(y))
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)#数据集比例划分
# Out:
# {0, 1, 2}

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0,class_weight = 'balanced')
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix , f1_score
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[2481,  477, 1900],
#        [1724,  665, 2100],
#        [4370, 1818, 6953]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(y_test,y_pred,average="macro")}')
result['Logistic_regression'] = f1_score(y_test,y_pred,average='macro')
# Out:
# confusion_matrix is:
# [[2481  477 1900]
#  [1724  665 2100]
#  [4370 1818 6953]]
# f1_score is: 0.37503080435772684

# %% [markdown]
# ### Support Vector Machine

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('dataset.csv')
dataset = dataset.dropna().reset_index(drop=True)
X = dataset.iloc[:,2:6].values
y = dataset.iloc[:,-2].values
print(set(y))

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting SVM to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0,class_weight = 'balanced')
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)
# Out:
# {0, 1, 2}

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(y_test,y_pred,average="macro")}')
result['Support_vector_Machine'] = f1_score(y_test,y_pred,average='macro')
# Out:
# confusion_matrix is:
# [[1881 1499 1478]
#  [ 952 1967 1570]
#  [2173 5689 5279]]
# f1_score is: 0.38717349341513957

# %% [markdown]
# ### Decision Tree

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier as DTC


# Importing the dataset
dataset = pd.read_csv('dataset.csv')
dataset = dataset.dropna().reset_index(drop=True)
X = dataset.iloc[:,2:6].values
y = dataset.iloc[:,-2].values


# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
# from sklearn.preprocessing import StandardScaler
# sc_X = StandardScaler()
# X_train = sc_X.fit_transform(X_train)
# X_test = sc_X.transform(X_test)

from sklearn.model_selection import GridSearchCV

tuned_parameters = [{'criterion': ['gini', 'entropy'],
                     'max_depth': [3, 5, 7],
                     'min_samples_split': [3, 5, 7],
                     'max_features': ["sqrt", "log2", None]}]

scores = ['f1_macro']

for score in scores:
    print("# Tuning hyperparameters for %s" % score)
    print("\n")
    clf = GridSearchCV(DTC(class_weight="balanced"), tuned_parameters, cv=5,
                       scoring= score)
    clf.fit(X_train, y_train)
    print("Best parameters set found on the training set:")
    print(clf.best_params_)
    print("\n")
# Out:
# # Tuning hyperparameters for f1_macro
#
#
# Best parameters set found on the training set:
# {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_split': 3}

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion ='entropy', max_depth = 5, class_weight='balanced', max_features = None , min_samples_split = 3)
classifier.fit(X_train,y_train)

# # Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,f1_score,accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(f'confusion_matrix is: \n{cm}')
print(f'f1_score is: {f1_score(y_test,y_pred,average="macro")}')
result['Decision_tree'] = f1_score(y_test,y_pred,average='macro')
# Out:
# confusion_matrix is:
# [[1045  737 2164]
#  [ 214  840 2502]
#  [ 411 2113 7965]]
# f1_score is: 0.43100563142945836

# %% [markdown]
# ### result

# %%
result
# Out:
# {'Random_forest': 0.4312991351436101,
#  'Logistic_regression': 0.37503080435772684,
#  'Support_vector_Machine': 0.38717349341513957,
#  'Decision_tree': 0.43100563142945836}

# %%
fig,ax = plt.subplots(figsize = (8,4))
ax.plot(list(result.values()))
ax.set_xticks(np.arange(4))
ax.set_xticklabels(result.keys())
ax.set_xlabel('Algorithms',size = 15)
ax.set_ylabel('F1-score',size = 15)
ax.set_title('3_Class Classification',size = 15)
# Out:
# Text(0.5, 1.0, '3_Class Classification')
